# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
rb_train = pd.read_csv('../data/final/rb_train_updated.csv')
rb_test = pd.read_csv('../data/final/rb_test_updated.csv')

# %%
rb_train[rb_train.player_display_name == 'Derrick Henry'].sample(3)
# Out:
#       season player_display_name  games  carries  rushing_yards  rushing_tds  \
# 1461    2023       Derrick Henry     17      280         1167.0           12
# 736     2016       Derrick Henry     14      110          490.0            5
# 833     2017       Derrick Henry     18      211          928.0            6
#
#       rushing_fumbles  rushing_fumbles_lost  rushing_first_downs  rushing_epa  \
# 1461              0.0                   0.0                 63.0    -2.098503
# 736               0.0                   0.0                 29.0    -0.293348
# 833               2.0                   0.0                 45.0   -11.590342
#
#       receptions  targets  receiving_yards_after_catch  receiving_first_downs  \
# 1461          28       36                        275.0                    7.0
# 736           13       15                        124.0                    6.0
# 833           16       23                        174.0                    5.0
#
#       receiving_epa  target_share  fantasy_points  salary_per_year  \
# 1461       3.174481      0.084112          218.66              8.0
# 736        3.780821      0.061475           92.70             12.5
# 833        5.051808      0.065341          154.00             12.5
#
#       smoothed_salary_per_year
# 1461                  9.225233
# 736                  13.564606
# 833                  13.564606

# %%
### using avg of the most recent 2 season stats before each contract 

rct_seasons_per_contract = (
    rb_train.sort_values(['player_display_name', 'salary_per_year', 'season'], ascending=[True, True, False])
            .groupby(['player_display_name', 'salary_per_year'])
            .head(2)
)

contract_latest = (
    rct_seasons_per_contract.groupby(['player_display_name', 'salary_per_year'])['season'].max().reset_index()
)

top_contracts_per_player = (
    contract_latest.sort_values(['player_display_name', 'season'], ascending=[True, False])
                   .groupby('player_display_name')
                   .head(2)
)

final = rct_seasons_per_contract.merge(top_contracts_per_player, on=['player_display_name', 'salary_per_year'])
final[final.player_display_name == 'Derrick Henry']
# Out:
#      season_x player_display_name  games  carries  rushing_yards  rushing_tds  \
# 242      2023       Derrick Henry     17      280         1167.0           12
# 243      2022       Derrick Henry     16      349         1538.0           13
# 244      2019       Derrick Henry     18      386         1986.0           18
# 245      2018       Derrick Henry     16      215         1059.0           12
#
#      rushing_fumbles  rushing_fumbles_lost  rushing_first_downs  rushing_epa  \
# 242              0.0                   0.0                 63.0    -2.098503
# 243              4.0                   2.0                 65.0   -22.311296
# 244              5.0                   3.0                 94.0     4.754160
# 245              0.0                   0.0                 51.0    10.600936
#
#      receptions  targets  receiving_yards_after_catch  receiving_first_downs  \
# 242          28       36                        275.0                    7.0
# 243          33       41                        397.0                   11.0
# 244          23       29                        275.0                    5.0
# 245          15       18                        115.0                    4.0
#
#      receiving_epa  target_share  fantasy_points  salary_per_year  \
# 242       3.174481      0.084112          218.66              8.0
# 243      14.124216      0.113260          269.76              8.0
# 244       6.436225      0.068558          339.42             12.5
# 245      -2.625590      0.055046          186.36             12.5
#
#      smoothed_salary_per_year  season_y
# 242                  9.225233      2023
# 243                  9.225233      2023
# 244                 13.564606      2019
# 245                 13.564606      2019

# %%
preds = [col for col in rb_train.columns if col not in ['season', 'player_display_name', 'salary_per_year', 'smoothed_salary_per_year']]
grouped_df = final.groupby(['player_display_name', 'smoothed_salary_per_year'])[preds].mean().reset_index()
grouped_df[grouped_df.player_display_name == 'Derrick Henry']
# Out:
#     player_display_name  smoothed_salary_per_year  games  carries  \
# 170       Derrick Henry                  9.225233   16.5    314.5
# 171       Derrick Henry                 13.564606   17.0    300.5
#
#      rushing_yards  rushing_tds  rushing_fumbles  rushing_fumbles_lost  \
# 170         1352.5         12.5              2.0                   1.0
# 171         1522.5         15.0              2.5                   1.5
#
#      rushing_first_downs  rushing_epa  receptions  targets  \
# 170                 64.0   -12.204900        30.5     38.5
# 171                 72.5     7.677548        19.0     23.5
#
#      receiving_yards_after_catch  receiving_first_downs  receiving_epa  \
# 170                        336.0                    9.0       8.649349
# 171                        195.0                    4.5       1.905317
#
#      target_share  fantasy_points
# 170      0.098686          244.21
# 171      0.061802          262.89

# %%
## filling na's with 0 -- only occur in the advanced metrics where player has no attempts
X = grouped_df[preds]
X = X.fillna(0)

y = grouped_df['smoothed_salary_per_year']

# %%
## lasso for feature selection 

from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)
y = grouped_df['smoothed_salary_per_year'].values.ravel()

lasso = LassoCV(cv=5, random_state=0)
lasso.fit(X, y)
# Out:
# LassoCV(cv=5, random_state=0)

# %%
lasso_coef = pd.Series(lasso.coef_, index=preds)
selected_features = lasso_coef[lasso_coef != 0].index.tolist()
print("Selected Features:", selected_features)
# Out:
# Selected Features: ['games', 'carries', 'rushing_yards', 'rushing_first_downs', 'rushing_epa', 'targets', 'receiving_yards_after_catch', 'receiving_epa', 'fantasy_points']

# %%
import statsmodels.api as sm

X_selected = X[selected_features]
X_selected = sm.add_constant(X_selected)

y = grouped_df['smoothed_salary_per_year'].values.ravel()  # flatten to 1D
ols_model = sm.OLS(y, X_selected).fit()

print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     75.80
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.79e-91
# Time:                        21:28:08   Log-Likelihood:                -1262.1
# No. Observations:                 579   AIC:                             2544.
# Df Residuals:                     569   BIC:                             2588.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.3802      0.187     -2.034      0.042      -0.747      -0.013
# games                          -0.1248      0.029     -4.263      0.000      -0.182      -0.067
# carries                        -0.0881      0.012     -7.626      0.000      -0.111      -0.065
# rushing_yards                   0.0117      0.002      5.424      0.000       0.007       0.016
# rushing_first_downs             0.1593      0.031      5.144      0.000       0.098       0.220
# rushing_epa                    -0.0801      0.018     -4.425      0.000      -0.116      -0.045
# targets                        -0.0264      0.011     -2.319      0.021      -0.049      -0.004
# receiving_yards_after_catch     0.0123      0.001      8.256      0.000       0.009       0.015
# receiving_epa                  -0.0639      0.017     -3.804      0.000      -0.097      -0.031
# fantasy_points                  0.0249      0.010      2.595      0.010       0.006       0.044
# ==============================================================================
# Omnibus:                      188.253   Durbin-Watson:                   1.467
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1202.705
# Skew:                           1.278   Prob(JB):                    6.85e-262
# Kurtosis:                       9.582   Cond. No.                     1.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X_test = rb_test[selected_features]
X_test = X_test.fillna(0)
X_test = sm.add_constant(X_test)

y_test = rb_test['smoothed_salary_per_year'].values.ravel()

y_pred = ols_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R² Score:", r2)
# Out:
# MSE: 2.2420439222989144
# RMSE: 1.4973456255316988
# MAE: 1.2281637321391503
# R² Score: 0.8147875432378877

# %%
rb_test['predicted_smoothed_salary'] = y_pred
rb_test.sample(10)
# Out:
#     season player_display_name  games  carries  rushing_yards  rushing_tds  \
# 12    2024     Darrynton Evans      1        3            3.0            0
# 6     2024       Miles Sanders     11       55          205.0            2
# 2     2024     Dare Ogunbowale     17       32          126.0            0
# 8     2024       Jonathan Ward      2        5           22.0            0
# 20    2024        Jordan Mason     12      153          789.0            3
# 17    2024    Javonte Williams     18      146          542.0            4
# 9     2024      Patrick Taylor      5       39          183.0            1
# 4     2024      Saquon Barkley     20      436         2504.0           18
# 18    2024       Tyler Goodson      9       32          153.0            1
# 1     2024       Samaje Perine     20       21          100.0            1
#
#     rushing_fumbles  rushing_fumbles_lost  rushing_first_downs  rushing_epa  \
# 12              0.0                   0.0                  0.0    -1.294813
# 6               0.0                   0.0                 12.0    -8.659847
# 2               0.0                   0.0                  5.0    -7.770873
# 8               0.0                   0.0                  1.0     0.204633
# 20              3.0                   1.0                 37.0    -5.442400
# 17              2.0                   2.0                 30.0   -24.837296
# 9               0.0                   0.0                 11.0     2.139868
# 4               2.0                   1.0                 99.0    30.810126
# 18              0.0                   0.0                  6.0     2.687648
# 1               0.0                   0.0                  8.0     0.036445
#
#     receptions  targets  receiving_yards_after_catch  receiving_first_downs  \
# 12           0        0                          0.0                    0.0
# 6           24       30                        150.0                    5.0
# 2           20       29                        174.0                    8.0
# 8            0        0                          0.0                    0.0
# 20          11       14                         59.0                    5.0
# 17          54       72                        408.0                   14.0
# 9            3       11                         19.0                    2.0
# 4           46       58                        337.0                   15.0
# 18          11       15                         67.0                    3.0
# 1           29       38                        330.0                   17.0
#
#     receiving_epa  target_share  fantasy_points  salary_per_year  \
# 12            NaN           NaN             0.3           1.2100
# 6      -17.532581      0.095847            53.3           1.3375
# 2        5.249691      0.068558            38.4           1.8000
# 8             NaN           NaN             2.2           1.1700
# 20       4.628491      0.059072           104.0           5.3460
# 17      -5.380488      0.125874           110.2           3.0000
# 9      -10.156942      0.083333            26.8           1.1700
# 4       16.555139      0.125541           409.7          20.6000
# 18       1.303773      0.069124            33.4           1.0300
# 1       16.013460      0.060800            55.9           1.8000
#
#     smoothed_salary_per_year  predicted_smoothed_salary
# 12                  0.197907                  -0.623138
# 6                   0.303606                   1.898633
# 2                   0.687027                  -0.437848
# 8                   0.164746                  -0.615670
# 20                  3.626722                   2.837834
# 17                  1.681848                   3.807647
# 9                   0.164746                   0.537147
# 4                  16.272552                  13.019499
# 18                  0.048683                  -0.619384
# 1                   0.687027                   1.133603
