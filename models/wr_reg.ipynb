# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
wr_train = pd.read_csv('../data/final/wr_train_updated.csv')
wr_test = pd.read_csv('../data/final/wr_test_updated.csv')

# %%
# Step 1: Get top 2 seasons per contract
top_seasons_per_contract = (
    wr_train.sort_values(['player_display_name', 'salary_per_year', 'season'], ascending=[True, True, False])
            .groupby(['player_display_name', 'salary_per_year'])
            .head(2)
)

# Step 2: Get the most recent season per contract (to sort contracts per player)
contract_latest = (
    top_seasons_per_contract.groupby(['player_display_name', 'salary_per_year'])['season'].max().reset_index()
)

# Step 3: Get top 2 contracts per player by latest season
top_contracts_per_player = (
    contract_latest.sort_values(['player_display_name', 'season'], ascending=[True, False])
                   .groupby('player_display_name')
                   .head(2)
)

# Step 4: Merge to keep only rows from top 2 contracts
final = top_seasons_per_contract.merge(top_contracts_per_player, on=['player_display_name', 'salary_per_year'])

# %%
preds = [col for col in wr_train.columns if col not in ['season', 'player_display_name', 'salary_per_year', 'smoothed_salary_per_year']]
grouped_df = final.groupby(['player_display_name', 'smoothed_salary_per_year'])[preds].mean().reset_index()
# Out:
#   player_display_name  smoothed_salary_per_year  games  receptions  targets  \
# 0          A.J. Brown                 22.065259   14.5        72.0    115.0
# 1          A.J. Brown                 25.122968   18.5       103.5    162.5
# 2          A.J. Green                  2.261734   17.0        54.0     95.0
# 3          A.J. Green                  5.575160   16.0        47.0    104.0
# 4        A.J. Jenkins                 -0.612286    7.5         9.0     16.5
#
#    receiving_yards  receiving_tds  receiving_yards_after_catch  \
# 0           1084.5            9.0                        351.5
# 1           1549.0            9.5                        538.0
# 2            848.0            3.0                        181.0
# 3            523.0            2.0                         86.0
# 4            125.0            0.0                         56.5
#
#    receiving_first_downs  receiving_epa  target_share  fantasy_points
# 0                   54.5      56.385506      0.270404          164.95
# 1                   68.5      63.470761      0.292725          207.90
# 2                   37.0      26.662374      0.164360          102.80
# 3                   34.0     -15.264712      0.183746           64.30
# 4                    5.0       4.435864      0.073488           12.70

# %%
X = grouped_df[preds]
X = X.fillna(0)

y = grouped_df['smoothed_salary_per_year']

# %%
## lasso for feature selection 

from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)
y = grouped_df['smoothed_salary_per_year'].values.ravel()

lasso = LassoCV(cv=5, random_state=0)
lasso.fit(X, y)
# Out:
# LassoCV(cv=5, random_state=0)

# %%
lasso_coef = pd.Series(lasso.coef_, index=preds)
selected_features = lasso_coef[lasso_coef != 0].index.tolist()
print("Selected Features:", selected_features)
# Out:
# Selected Features: ['games', 'targets', 'receiving_yards', 'receiving_yards_after_catch', 'fantasy_points']

# %%
import statsmodels.api as sm

X_selected = X[selected_features]
X_selected = sm.add_constant(X_selected)

y = grouped_df['smoothed_salary_per_year'].values.ravel()
ols_model = sm.OLS(y, X_selected).fit()

print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):          8.83e-151
# Time:                        21:51:22   Log-Likelihood:                -2269.5
# No. Observations:                 897   AIC:                             4551.
# Df Residuals:                     891   BIC:                             4580.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.0078      0.206     -0.038      0.970      -0.413       0.397
# games                          -0.2397      0.034     -7.106      0.000      -0.306      -0.174
# targets                        -0.0106      0.011     -0.977      0.329      -0.032       0.011
# receiving_yards                 0.0035      0.002      1.496      0.135      -0.001       0.008
# receiving_yards_after_catch     0.0153      0.002      8.548      0.000       0.012       0.019
# fantasy_points                  0.0304      0.013      2.360      0.018       0.005       0.056
# ==============================================================================
# Omnibus:                      253.353   Durbin-Watson:                   1.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1811.992
# Skew:                           1.089   Prob(JB):                         0.00
# Kurtosis:                       9.613   Cond. No.                     1.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X_test = wr_test[selected_features]
X_test = X_test.fillna(0)
X_test = sm.add_constant(X_test)

y_test = wr_test['smoothed_salary_per_year'].values.ravel()

y_pred = ols_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R² Score:", r2)
# Out:
# MSE: 5.760024985848884
# RMSE: 2.4000052053795393
# MAE: 1.4851469058082527
# R² Score: 0.6067314907640325

# %%
wr_test['predicted_smoothed_salary'] = y_pred
wr_test.sample(10)
# Out:
#     season player_display_name  games  receptions  targets  receiving_yards  \
# 22    2024          Cody White      1           2        3             44.0
# 28    2024        Jalen Reagor      7           7       12            100.0
# 47    2024         Ronnie Bell      3           2        6             22.0
# 44    2024       Kendric Pryor      1           1        1              9.0
# 31    2024    D'Wayne Eskridge      3           3        3             44.0
# 39    2024           Bo Melton     12           9       20            107.0
# 32    2024         Dyami Brown     18          44       58            537.0
# 14    2024      KhaDarel Hodge      6           7       12            131.0
# 41    2024         Justyn Ross      1           0        1              0.0
# 26    2024  Kristian Wilkerson      1           2        3             18.0
#
#     receiving_tds  receiving_yards_after_catch  receiving_first_downs  \
# 22              0                         13.0                    2.0
# 28              0                         26.0                    3.0
# 47              0                          2.0                    1.0
# 44              0                          0.0                    0.0
# 31              0                         29.0                    2.0
# 39              0                          7.0                    6.0
# 32              2                        309.0                   22.0
# 14              1                         89.0                    6.0
# 41              0                          0.0                    0.0
# 26              1                         11.0                    2.0
#
#     receiving_epa  target_share  fantasy_points  salary_per_year  \
# 22       2.547461      0.088235             4.4           1.0300
# 28      -7.275862      0.057416             7.7           1.3375
# 47      -4.306386      0.069767             2.2           1.0300
# 44       0.680168      0.027027             0.9           1.0300
# 31       3.129415      0.032258             4.4           1.2700
# 39      -4.357463      0.062893            16.1           1.0300
# 32      11.172550      0.104882            64.3          10.0000
# 14       8.256851      0.067039            25.1           2.7500
# 41      -1.216528      0.025000             0.0           0.9600
# 26       2.861493      0.081081             7.8           1.1000
#
#     smoothed_salary_per_year  predicted_smoothed_salary
# 22                 -0.107225                   0.206800
# 28                  0.097960                  -0.832183
# 47                 -0.107225                  -0.616127
# 44                 -0.107225                  -0.199311
# 31                  0.052920                  -0.027899
# 39                 -0.107225                  -2.125972
# 32                  5.878179                   3.617561
# 14                  1.040478                   1.008279
# 41                 -0.153934                  -0.258048
# 26                 -0.060516                   0.189004
